# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv')
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford               2002.0     Oxford University Press
# 1  Richard Bruce Wright               2001.0       HarperFlamingo Canada
# 2          Carlo D'Este               1991.0             HarperPerennial
# 3      Gina Bari Kolata               1999.0        Farrar Straus Giroux
# 4       E. J. W. Barber               1999.0  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (15868, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    1
# Publisher              1
# Image-URL-S            1
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                            Book-Title  num_ratings
# 0                                        It Takes Two            2
# 1                        Tales of Terror and Suspense            1
# 2                                                 '48            4
# 3                                        'Salem's Lot           32
# 4             .Hack: //Legend of the Twilight, Vol. 1            5
# ...                                               ...          ...
# 14975  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            3
# 14976                                        stardust           51
# 14977                Â¿QuiÃ©n se ha llevado mi queso?            2
# 14978                        Â¿QuÃ© me quieres, amor?            9
# 14979                           Ã?Â?ber die Freiheit.            1
#
# [14980 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                            Book-Title  avg_rating
# 0                                        It Takes Two    0.000000
# 1                        Tales of Terror and Suspense    0.000000
# 2                                                 '48    0.000000
# 3                                        'Salem's Lot    3.406250
# 4             .Hack: //Legend of the Twilight, Vol. 1    6.400000
# ...                                               ...         ...
# 14975  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)    6.000000
# 14976                                        stardust    4.137255
# 14977                Â¿QuiÃ©n se ha llevado mi queso?    7.500000
# 14978                        Â¿QuÃ© me quieres, amor?    3.000000
# 14979                           Ã?Â?ber die Freiheit.    7.000000
#
# [14980 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                            Book-Title  num_ratings  avg_rating
# 0                                        It Takes Two            2    0.000000
# 1                        Tales of Terror and Suspense            1    0.000000
# 2                                                 '48            4    0.000000
# 3                                        'Salem's Lot           32    3.406250
# 4             .Hack: //Legend of the Twilight, Vol. 1            5    6.400000
# ...                                               ...          ...         ...
# 14975  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            3    6.000000
# 14976                                        stardust           51    4.137255
# 14977                Â¿QuiÃ©n se ha llevado mi queso?            2    7.500000
# 14978                        Â¿QuÃ© me quieres, amor?            9    3.000000
# 14979                           Ã?Â?ber die Freiheit.            1    7.000000
#
# [14980 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
read_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(read_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     3363    6251    \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# ...                                                    ...     ...     ...
# When the Wind Blows                                    0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0    10.0     0.0
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             6575    7346    11601   \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     1.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     7.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# ...                                                    ...     ...     ...
# When the Wind Blows                                    0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     8.0     0.0     0.0
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             11676   12538   13273   \
# Book-Title
# 1st to Die: A Novel                                    9.0     0.0     0.0
# 2nd Chance                                             7.5     0.0     0.0
# A Bend in the Road                                     6.5     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Painted House                                        9.0     0.0     0.0
# ...                                                    ...     ...     ...
# When the Wind Blows                                    5.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))    10.0     0.0     9.0
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wild Animus                                            6.0     0.0     0.0
#
# User-ID                                             13552   ...  262399  \
# Book-Title                                                  ...
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0  ...     0.0
# A Painted House                                        0.0  ...     0.0
# ...                                                    ...  ...     ...
# When the Wind Blows                                    0.0  ...     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0  ...     0.0
# While I Was Gone                                       0.0  ...     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0  ...     0.0
# Wild Animus                                            0.0  ...     0.0
#
# User-ID                                             265115  265313  266226  \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     7.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# ...                                                    ...     ...     ...
# When the Wind Blows                                    0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0     0.0     0.0
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             268330  269566  271284  \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# ...                                                    ...     ...     ...
# When the Wind Blows                                    0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0     0.0     0.0
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             274308  275970  278418
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# ...                                                    ...     ...     ...
# When the Wind Blows                                    0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0     0.0     0.0
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# [115 rows x 178 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (115, 115)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('While I Was Gone')
# Out:
# [["Songs in Ordinary Time (Oprah's Book Club (Paperback))",
#   'Mary McGarry Morris',
#   'http://images.amazon.com/images/P/0140244824.01.MZZZZZZZ.jpg'],
#  ['Back Roads',
#   "Tawni O'Dell",
#   'http://images.amazon.com/images/P/0451202341.01.MZZZZZZZ.jpg'],
#  ['The Bridges of Madison County',
#   'Robert James Waller',
#   'http://images.amazon.com/images/P/044651652X.01.MZZZZZZZ.jpg'],
#  ['Snow Falling on Cedars',
#   'David Guterson',
#   'http://images.amazon.com/images/P/0151001006.01.MZZZZZZZ.jpg']]

# %%
pt.index[100]
# Out:
# 'The Testament'

# %%
pt.index[112]
# Out:
# 'While I Was Gone'

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#              ISBN                                         Book-Title  \
# 0      0195153448                                Classical Mythology
# 1      0002005018                                       Clara Callan
# 2      0060973129                               Decision in Normandy
# 3      0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4      0393045218                             The Mummies of Urumchi
# ...           ...                                                ...
# 15863  0316353299             Blue Highways : A Journey into America
# 15864  1869503171                                     Spirit Writing
# 15865  0767903862                             In a Sunburned Country
# 15866  0060931671                               The Crying of Lot 49
# 15867  0060730552                                    Touching the Vo
#
#                    Book-Author  Year-Of-Publication  \
# 0           Mark P. O. Morford               2002.0
# 1         Richard Bruce Wright               2001.0
# 2                 Carlo D'Este               1991.0
# 3             Gina Bari Kolata               1999.0
# 4              E. J. W. Barber               1999.0
# ...                        ...                  ...
# 15863  William Least Heat-Moon               1999.0
# 15864          Adrienne Jansen               1999.0
# 15865              Bill Bryson               2001.0
# 15866           Thomas Pynchon               1999.0
# 15867                      NaN                  NaN
#
#                         Publisher  \
# 0         Oxford University Press
# 1           HarperFlamingo Canada
# 2                 HarperPerennial
# 3            Farrar Straus Giroux
# 4      W. W. Norton &amp; Company
# ...                           ...
# 15863              Back Bay Books
# 15864   HarperCollins New Zealand
# 15865              Broadway Books
# 15866          Perennial Classics
# 15867                         NaN
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/0195153448.0...
# 1      http://images.amazon.com/images/P/0002005018.0...
# 2      http://images.amazon.com/images/P/0060973129.0...
# 3      http://images.amazon.com/images/P/0374157065.0...
# 4      http://images.amazon.com/images/P/0393045218.0...
# ...                                                  ...
# 15863  http://images.amazon.com/images/P/0316353299.0...
# 15864  http://images.amazon.com/images/P/1869503171.0...
# 15865  http://images.amazon.com/images/P/0767903862.0...
# 15866  http://images.amazon.com/images/P/0060931671.0...
# 15867                                                NaN
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/0195153448.0...
# 1      http://images.amazon.com/images/P/0002005018.0...
# 2      http://images.amazon.com/images/P/0060973129.0...
# 3      http://images.amazon.com/images/P/0374157065.0...
# 4      http://images.amazon.com/images/P/0393045218.0...
# ...                                                  ...
# 15863  http://images.amazon.com/images/P/0316353299.0...
# 15864  http://images.amazon.com/images/P/1869503171.0...
# 15865  http://images.amazon.com/images/P/0767903862.0...
# 15866  http://images.amazon.com/images/P/0060931671.0...
# 15867                                                NaN
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/0195153448.0...
# 1      http://images.amazon.com/images/P/0002005018.0...
# 2      http://images.amazon.com/images/P/0060973129.0...
# 3      http://images.amazon.com/images/P/0374157065.0...
# 4      http://images.amazon.com/images/P/0393045218.0...
# ...                                                  ...
# 15863  http://images.amazon.com/images/P/0316353299.0...
# 15864  http://images.amazon.com/images/P/1869503171.0...
# 15865  http://images.amazon.com/images/P/0767903862.0...
# 15866  http://images.amazon.com/images/P/0060931671.0...
# 15867                                                NaN
#
# [14988 rows x 8 columns]

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
